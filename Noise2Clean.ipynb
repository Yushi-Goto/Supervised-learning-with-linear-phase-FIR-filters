# %%
# !apt-get install imagemagick

# %%
# !convert -version

# %% [markdown]
# 通常のCNNカーネル（前処理あり）

# %%
# !python main.py --mode 'train' --batch-size 32 --epochs 50

# %%
# !python main.py --mode 'test' --batch-size 32

# %%
# !python main.py --mode 'run' --data-path ./pengin.png

# %% [markdown]
# 線形位相性を持つCNNカーネル（前処理なし）

# %%
# !python main.py --mode 'train' --batch-size 32 --epochs 50 --model-path './N2CModel_lpfir.pht' --lpfir

# %%
# !python main.py --mode 'test' --batch-size 32 --model-path './N2CModel_lpfir.pht'

# %%
# !python main.py --mode 'run' --data-path ./pengin.png --model-path './N2CModel_lpfir.pht'

# %% [markdown]
# 通常のCNNカーネル（前処理なし）

# %%
# !python main.py --mode 'train' --batch-size 32 --epochs 50 --model-path './N2CModel_no-rf.pht' --no-rf

# %%
# !python main.py --mode 'test' --batch-size 32 --model-path './N2CModel_no-rf.pht'

# %%
# !python main.py --mode 'run' --data-path ./pengin.png --model-path './N2CModel_no-rf.pht'
